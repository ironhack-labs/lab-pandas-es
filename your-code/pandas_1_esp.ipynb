# %% [markdown]
# # Laboratorio de Introducción a Pandas
#
# Completa el siguiente conjunto de ejercicios para consolidar tu conocimiento de los fundamentos de Pandas.
#
# ### 1. Importa Numpy y Pandas y asígnalos los alias `np` y `pd` respectivamente.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Crea una Serie de Pandas que contenga los elementos de la lista a continuación.

# %%
lst = [5.7, 75.2, 74.4, 84.0, 66.5, 66.3, 55.8, 75.7, 29.1, 43.7]

# %%
series = pd.Series(lst)
print(series)
# Out:
# 0     5.7
# 1    75.2
# 2    74.4
# 3    84.0
# 4    66.5
# 5    66.3
# 6    55.8
# 7    75.7
# 8    29.1
# 9    43.7
# dtype: float64

# %% [markdown]
# ### 3. Usa la indexación para devolver el tercer valor en la Serie anterior.
#
# *Sugerencia: Recuerda que la indexación comienza en 0.*

# %%
series[2]
# Out:
# 74.4

# %% [markdown]
# ### 4. Crea un DataFrame de Pandas a partir de la lista de listas a continuación. Cada sublista debe representarse como una fila.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
df = pd.DataFrame(b)
df
# Out:
#       0     1     2     3     4
# 0  53.1  95.0  67.5  35.0  78.4
# 1  61.3  40.8  30.8  37.8  87.6
# 2  20.6  73.2  44.2  14.6  91.8
# 3  57.4   0.1  96.1   4.2  69.5
# 4  83.6  20.5  85.4  22.8  35.9
# 5  49.0  69.0   0.1  31.8  89.1
# 6  23.3  40.7  95.0  83.8  26.9
# 7  27.6  26.4  53.8  88.8  68.5
# 8  96.6  96.4  53.4  72.4  50.1
# 9  73.7  39.0  43.2  81.6  34.7

# %% [markdown]
# ### 5. Renombra las columnas del DataFrame basándote en los nombres de la lista a continuación.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
df = pd.DataFrame(b, columns = ['Score_1', 'Score_2', 'Score_3', 'Score_4', 'Score_5'])
df
# Out:
#    Score_1  Score_2  Score_3  Score_4  Score_5
# 0     53.1     95.0     67.5     35.0     78.4
# 1     61.3     40.8     30.8     37.8     87.6
# 2     20.6     73.2     44.2     14.6     91.8
# 3     57.4      0.1     96.1      4.2     69.5
# 4     83.6     20.5     85.4     22.8     35.9
# 5     49.0     69.0      0.1     31.8     89.1
# 6     23.3     40.7     95.0     83.8     26.9
# 7     27.6     26.4     53.8     88.8     68.5
# 8     96.6     96.4     53.4     72.4     50.1
# 9     73.7     39.0     43.2     81.6     34.7

# %% [markdown]
# ### 6. Crea un subconjunto de este DataFrame que contenga solo las columnas de Puntuación 1, 3 y 5.

# %%
scores135 = df[['Score_1', 'Score_3', 'Score_5']]
scores135
# Out:
#    Score_1  Score_3  Score_5
# 0     53.1     67.5     78.4
# 1     61.3     30.8     87.6
# 2     20.6     44.2     91.8
# 3     57.4     96.1     69.5
# 4     83.6     85.4     35.9
# 5     49.0      0.1     89.1
# 6     23.3     95.0     26.9
# 7     27.6     53.8     68.5
# 8     96.6     53.4     50.1
# 9     73.7     43.2     34.7

# %% [markdown]
# ### 7. Del DataFrame original, calcula el valor promedio de Score_3.

# %%
df['Score_3'].mean()
# Out:
# 56.95000000000001

# %% [markdown]
# ### 8. Del DataFrame original, calcula el máximo valor del Score_4.

# %%
df['Score_4'].max()
# Out:
# 88.8

# %% [markdown]
# ### 9. Del DataFrame original, calcula la mediana del Score_2.

# %%
df['Score_2'].median()
# Out:
# 40.75

# %% [markdown]
# ### 10. Crea un DataFrame de Pandas a partir del diccionario de pedidos de productos a continuación.

# %%
orders = {'Description': ['LUNCH BAG APPLE DESIGN',
  'SET OF 60 VINTAGE LEAF CAKE CASES ',
  'RIBBON REEL STRIPES DESIGN ',
  'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
  'PLAYING CARDS JUBILEE UNION JACK',
  'POPCORN HOLDER',
  'BOX OF VINTAGE ALPHABET BLOCKS',
  'PARTY BUNTING',
  'JAZZ HEARTS ADDRESS BOOK',
  'SET OF 4 SANTA PLACE SETTINGS'],
 'Quantity': [1, 24, 1, 2880, 2, 7, 1, 4, 10, 48],
 'UnitPrice': [1.65, 0.55, 1.65, 0.18, 1.25, 0.85, 11.95, 4.95, 0.19, 1.25],
 'Revenue': [1.65, 13.2, 1.65, 518.4, 2.5, 5.95, 11.95, 19.8, 1.9, 60.0]}

# %%
# Se elimina la descripción inicial del diccionario
# orders.pop('Description')
# Out:
# ['LUNCH BAG APPLE DESIGN',
#  'SET OF 60 VINTAGE LEAF CAKE CASES ',
#  'RIBBON REEL STRIPES DESIGN ',
#  'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
#  'PLAYING CARDS JUBILEE UNION JACK',
#  'POPCORN HOLDER',
#  'BOX OF VINTAGE ALPHABET BLOCKS',
#  'PARTY BUNTING',
#  'JAZZ HEARTS ADDRESS BOOK',
#  'SET OF 4 SANTA PLACE SETTINGS']

# %%
df = pd.DataFrame(orders)
df
# Out:
#                           Description  Quantity  UnitPrice  Revenue
# 0              LUNCH BAG APPLE DESIGN         1       1.65     1.65
# 1  SET OF 60 VINTAGE LEAF CAKE CASES         24       0.55    13.20
# 2         RIBBON REEL STRIPES DESIGN          1       1.65     1.65
# 3   WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880       0.18   518.40
# 4    PLAYING CARDS JUBILEE UNION JACK         2       1.25     2.50
# 5                      POPCORN HOLDER         7       0.85     5.95
# 6      BOX OF VINTAGE ALPHABET BLOCKS         1      11.95    11.95
# 7                       PARTY BUNTING         4       4.95    19.80
# 8            JAZZ HEARTS ADDRESS BOOK        10       0.19     1.90
# 9       SET OF 4 SANTA PLACE SETTINGS        48       1.25    60.00

# %% [markdown]
# ### 11. Calcula la cantidad total pedida y los ingresos generados a partir de estos pedidos.

# %%
# Se suman los valores de toda la columna de cantidad
cantidad_total_pedida = df["Quantity"].sum()
print(cantidad_total_pedida)
# Out:
# 2978

# %%
# Primero se multiplican las cantidades vendidas por el precio unitario para obtener la ganancia por cada elemento.
# Después se suman las ganancias de todos los elementos.
ingresos_generados = (df["Quantity"]*df["UnitPrice"]).sum()
print(ingresos_generados)
# Out:
# 637.0

# %%
# Lo anterior es equivalente a sumar directamente las ganancias de cada elemento (los Revenues)
ingresos_generados = df["Revenue"].sum()
print(ingresos_generados)
# Out:
# 637.0

# %% [markdown]
# ### 12. Obtén los precios del artículo más caro y del más barato pedidos e imprime la diferencia.

# %%
print("El precio del producto más caro es ", df["UnitPrice"].max())
print("El precio del producto más caro es ", df["UnitPrice"].min())
# Out:
# El precio del producto más caro es  11.95
# El precio del producto más caro es  0.18

# %%
print("La diferencia entre el precio del producto más caro y el más barato es ",df["UnitPrice"].max() - df["UnitPrice"].min())
# Out:
# La diferencia entre el precio del producto más caro y el más barato es  11.77

# %% [markdown]
# ## Carguemos otro conjunto de datos para más ejercicios

# %%
# Sincronizo GoogleColab con Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cargo el conjunto de datos en la ruta donde lo tengo del Drive.
admissions = pd.read_csv("/content/drive/MyDrive/IronHack/Admission_Predict.csv")

# %%
# admissions = pd.read_csv('../Admission_Predict.csv')

# %% [markdown]
# Evaluemos el conjunto de datos mirando la función `head`.

# %%
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        316          104                  3  3.0   3.5  8.00
# 2           3        322          110                  3  3.5   2.5  8.67
# 3           4        314          103                  2  2.0   3.0  8.21
# 4           5        330          115                  5  4.5   3.0  9.34
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.72
# 2         1              0.80
# 3         0              0.65
# 4         1              0.90

# %% [markdown]
# ### 1 - Antes de comenzar a trabajar con este conjunto de datos y evaluar los datos de admisiones de posgrado, verificaremos que no haya datos faltantes en el conjunto de datos. Haz esto en la celda de abajo.

# %%
admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         385 non-null    int64
#  1   GRE Score          385 non-null    int64
#  2   TOEFL Score        385 non-null    int64
#  3   University Rating  385 non-null    int64
#  4   SOP                385 non-null    float64
#  5   LOR                385 non-null    float64
#  6   CGPA               385 non-null    float64
#  7   Research           385 non-null    int64
#  8   Chance of Admit    385 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 27.2 KB

# %% [markdown]
# ###  2 -  Curiosamente, hay una columna que identifica de manera única a los solicitantes. Esta columna es la columna de número de serie. En lugar de tener nuestro propio índice, deberíamos hacer de esta columna nuestro índice. Haz esto en la celda de abajo. Mantén la columna en el marco de datos además de hacerla un índice.

# %%
admissions.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
# Se configura un nuevo índice.
# inplace=True implica que el dataframe original se reescribe.
# Si fuese inplace=False se crearía un nuevo dataframe con los cambios.

admissions.set_index('Serial No.', inplace=True)
admissions.tail(2)
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 384               312          103                  3  3.5   4.0  8.78
# 385               333          117                  4  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 384                0              0.67
# 385                1              0.95

# %%
admissions.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %% [markdown]
# Resulta que `GRE Score` y `CGPA` también identifican de manera única los datos. Muestra esto en la celda de abajo.

# %%
""" Lo que se nos pide y significa el enunciado es que no debería haber dos filas
 en el DataFrame con los mismos valores tanto en GRE Score como en CGPA. """

# %%
# Del dataframe original se seleccionan solo los valores de 'GRE Score' y 'CGPA'
GRE_CGPA = admissions[['GRE Score', 'CGPA']]

# Encontrar duplicados basados en 'GRE Score' y 'CGPA'
# .duplicated() marca filas como True si hay alguna fila anterior igual a esa. False si no.
duplicated_rows = GRE_CGPA.duplicated()

# Si algun elemento de está duplicado (algún True en duplicated_rows)
if any(duplicated_rows):
    print("Hay filas con iguales 'GRE Score' y 'CGPA'.")
    print("Las filas duplicadas son: ")
    print(admissions[duplicated_rows])
else:
    print("No hay filas con iguales 'GRE Score' y 'CGPA.")
    print("Por tanto, 'GRE Score' y 'CGPA se identifican de forma única.")
# Out:
# No hay filas con iguales 'GRE Score' y 'CGPA.
# Por tanto, 'GRE Score' y 'CGPA se identifican de forma única.

# %% [markdown]
# ### 3 - En esta parte del laboratorio, nos gustaría probar condiciones complejas en todo el conjunto de datos de una vez. Comencemos encontrando el número de filas donde el CGPA es mayor a 9 y el estudiante ha realizado una investigación.

# %%
# Se aplica la condición donde CGPA es mayor que 9. La salida es una máscara Serie de False y True según la condición.
mask_CGPA_greater_than_9 = admissions["CGPA"] > 9

# Se aplica la condición donde Research se hizo (es 1). La salida es una máscara Serie de False y True según la condición.
mask_Research_done = admissions["Research"] == 1

# Se combinan las conficiones con un AND (&). La salida es una máscara Serie de True donde ambas eran True y False en el resto.
final_mask = mask_CGPA_greater_than_9 & mask_Research_done

# Se filtra el dataframe según la máscara final
admissions[final_mask]
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 5                 330          115                  5  4.5   3.0  9.34
# 11                328          112                  4  4.0   4.5  9.10
# 20                328          116                  5  5.0   5.0  9.50
# 21                334          119                  5  5.0   4.5  9.70
# ...               ...          ...                ...  ...   ...   ...
# 380               329          111                  4  4.5   4.0  9.23
# 381               324          110                  3  3.5   3.5  9.04
# 382               325          107                  3  3.0   3.5  9.11
# 383               330          116                  4  5.0   4.5  9.45
# 385               333          117                  4  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# ...

# %%
# De forma compacta lo anterior es:
admissions[(admissions["CGPA"] > 9) & (admissions["Research"] == 1)]
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 5                 330          115                  5  4.5   3.0  9.34
# 11                328          112                  4  4.0   4.5  9.10
# 20                328          116                  5  5.0   5.0  9.50
# 21                334          119                  5  5.0   4.5  9.70
# ...               ...          ...                ...  ...   ...   ...
# 380               329          111                  4  4.5   4.0  9.23
# 381               324          110                  3  3.5   3.5  9.04
# 382               325          107                  3  3.0   3.5  9.11
# 383               330          116                  4  5.0   4.5  9.45
# 385               333          117                  4  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# ...

# %% [markdown]
# ### 4 - Ahora devuelve todas las filas donde el CGPA es mayor a 9 y la puntuación SOP es menor a 3.5. Encuentra la probabilidad media de admisión para estos solicitantes.

# %%
# De forma compacta directamente:
# Del dataframe admissions se seleccionan donde se cumple lo pedido.
selection = admissions[(admissions["CGPA"] > 9) & (admissions["SOP"] < 3.5)]
selection
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 29                338          118                  4  3.0   4.5  9.40
# 63                327          114                  3  3.0   3.0  9.02
# 141               326          114                  3  3.0   3.0  9.11
# 218               324          111                  4  3.0   3.0  9.01
# 382               325          107                  3  3.0   3.5  9.11
#
#             Research  Chance of Admit
# Serial No.
# 29                 1              0.91
# 63                 0              0.61
# 141                1              0.83
# 218                1              0.82
# 382                1              0.84

# %%
# De la selección anterior se hace la media de la columna 'Chance of Admit'
selection["Chance of Admit "].mean()
# Out:
# 0.8019999999999999
