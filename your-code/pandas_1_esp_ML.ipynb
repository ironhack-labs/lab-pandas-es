# %% [markdown]
# # Laboratorio de Introducción a Pandas
#
# Completa el siguiente conjunto de ejercicios para consolidar tu conocimiento de los fundamentos de Pandas.
#
# ### 1. Importa Numpy y Pandas y asígnalos los alias `np` y `pd` respectivamente.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Crea una Serie de Pandas que contenga los elementos de la lista a continuación.

# %%
lst = [5.7, 75.2, 74.4, 84.0, 66.5, 66.3, 55.8, 75.7, 29.1, 43.7]

# %%
# Tu código aquí
serie = pd.Series(lst)
serie
# Out:
# 0     5.7
# 1    75.2
# 2    74.4
# 3    84.0
# 4    66.5
# 5    66.3
# 6    55.8
# 7    75.7
# 8    29.1
# 9    43.7
# dtype: float64

# %% [markdown]
# ### 3. Usa la indexación para devolver el tercer valor en la Serie anterior.
#
# *Sugerencia: Recuerda que la indexación comienza en 0.*

# %%
# Tu código aquí
serie[2]
# Out:
# 74.4

# %% [markdown]
# ### 4. Crea un DataFrame de Pandas a partir de la lista de listas a continuación. Cada sublista debe representarse como una fila.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
# Tu código aquí
df = pd.DataFrame(b)
df
# Out:
#       0     1     2     3     4
# 0  53.1  95.0  67.5  35.0  78.4
# 1  61.3  40.8  30.8  37.8  87.6
# 2  20.6  73.2  44.2  14.6  91.8
# 3  57.4   0.1  96.1   4.2  69.5
# 4  83.6  20.5  85.4  22.8  35.9
# 5  49.0  69.0   0.1  31.8  89.1
# 6  23.3  40.7  95.0  83.8  26.9
# 7  27.6  26.4  53.8  88.8  68.5
# 8  96.6  96.4  53.4  72.4  50.1
# 9  73.7  39.0  43.2  81.6  34.7

# %% [markdown]
# ### 5. Renombra las columnas del DataFrame basándote en los nombres de la lista a continuación.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
# Tu código aquí
columna = ['col1', 'col2', 'col3', 'col4', 'col5']

df = pd.DataFrame(b, columns=columna)
df
# Out:
#    col1  col2  col3  col4  col5
# 0  53.1  95.0  67.5  35.0  78.4
# 1  61.3  40.8  30.8  37.8  87.6
# 2  20.6  73.2  44.2  14.6  91.8
# 3  57.4   0.1  96.1   4.2  69.5
# 4  83.6  20.5  85.4  22.8  35.9
# 5  49.0  69.0   0.1  31.8  89.1
# 6  23.3  40.7  95.0  83.8  26.9
# 7  27.6  26.4  53.8  88.8  68.5
# 8  96.6  96.4  53.4  72.4  50.1
# 9  73.7  39.0  43.2  81.6  34.7

# %% [markdown]
# ### 6. Crea un subconjunto de este DataFrame que contenga solo las columnas de Puntuación 1, 3 y 5.

# %%
# Tu código aquí
#df_1 = list(df.columns)[0][2][4]

#df[df_1]

df1  =df[["col1", "col3","col5"]]
df1
# Out:
#    col1  col3  col5
# 0  53.1  67.5  78.4
# 1  61.3  30.8  87.6
# 2  20.6  44.2  91.8
# 3  57.4  96.1  69.5
# 4  83.6  85.4  35.9
# 5  49.0   0.1  89.1
# 6  23.3  95.0  26.9
# 7  27.6  53.8  68.5
# 8  96.6  53.4  50.1
# 9  73.7  43.2  34.7

# %% [markdown]
# ### 7. Del DataFrame original, calcula el valor promedio de Score_3.

# %%
# Tu código aquí
mean = df1[['col3']].mean()

print(f'el promedio de la columna 3 es {mean}')
# Out:
# el promedio de la columna 3 es col3    56.95
# dtype: float64

# %% [markdown]
# ### 8. Del DataFrame original, calcula el máximo valor del Score_4.

# %%
# Tu código aquí
max = df[['col4']].max()

print(f'el valor máximo de la columna 4 es {max}')
# Out:
# el valor máximo de la columna 4 es col4    88.8
# dtype: float64

# %% [markdown]
# ### 9. Del DataFrame original, calcula la media valor del Score_2.

# %%
# Tu código aquí

median = df[['col2']].median()
print(f'el valor memdio de la columna 2 es {median}')
# Out:
# el valor memdio de la columna 2 es col2    40.75
# dtype: float64

# %% [markdown]
# ### 10. Crea un DataFrame de Pandas a partir del diccionario de pedidos de productos a continuación.

# %%
orders = {'Description': ['LUNCH BAG APPLE DESIGN',
  'SET OF 60 VINTAGE LEAF CAKE CASES ',
  'RIBBON REEL STRIPES DESIGN ',
  'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
  'PLAYING CARDS JUBILEE UNION JACK',
  'POPCORN HOLDER',
  'BOX OF VINTAGE ALPHABET BLOCKS',
  'PARTY BUNTING',
  'JAZZ HEARTS ADDRESS BOOK',
  'SET OF 4 SANTA PLACE SETTINGS'],
 'Quantity': [1, 24, 1, 2880, 2, 7, 1, 4, 10, 48],
 'UnitPrice': [1.65, 0.55, 1.65, 0.18, 1.25, 0.85, 11.95, 4.95, 0.19, 1.25],
 'Revenue': [1.65, 13.2, 1.65, 518.4, 2.5, 5.95, 11.95, 19.8, 1.9, 60.0]}

# %%
# Tu código aquí
df_2 = pd.DataFrame(orders)
df_2
# Out:
#                           Description  Quantity  UnitPrice  Revenue
# 0              LUNCH BAG APPLE DESIGN         1       1.65     1.65
# 1  SET OF 60 VINTAGE LEAF CAKE CASES         24       0.55    13.20
# 2         RIBBON REEL STRIPES DESIGN          1       1.65     1.65
# 3   WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880       0.18   518.40
# 4    PLAYING CARDS JUBILEE UNION JACK         2       1.25     2.50
# 5                      POPCORN HOLDER         7       0.85     5.95
# 6      BOX OF VINTAGE ALPHABET BLOCKS         1      11.95    11.95
# 7                       PARTY BUNTING         4       4.95    19.80
# 8            JAZZ HEARTS ADDRESS BOOK        10       0.19     1.90
# 9       SET OF 4 SANTA PLACE SETTINGS        48       1.25    60.00

# %% [markdown]
# ### 11. Calcula la cantidad total pedida y los ingresos generados a partir de estos pedidos.

# %%
# Tu código aquí
df_2[['Quantity','Revenue']].sum()
# Out:
# Quantity    2978.0
# Revenue      637.0
# dtype: float64

# %% [markdown]
# ### 12. Obten los precios del artículo más caro y del más barato pedidos e imprime la diferencia.

# %%
# Tu código aquí

min1 = df_2[['UnitPrice']].min()
max1 = df_2[['UnitPrice']].max()
dif1 = max1 - min1

print(f'el articulo mas caro cuesta ${max1} mientras que el mas económico cuesta ${min1} siendo la diferencia entre elos de ${dif1}')
# Out:
# el articulo mas caro cuesta $UnitPrice    11.95
# dtype: float64 mientras que el mas económico cuesta $UnitPrice    0.18
# dtype: float64 siendo la diferencia entre elos de $UnitPrice    11.77
# dtype: float64

# %% [markdown]
# ## Carguemos otro conjunto de datos para más ejercicios

# %%
# Tu código aquí
admissions = pd.read_csv('C:/Users/manue/OneDrive/Documentos/IRONHACK Data Scientist/13 - Session XII Python APIs/LAB 1/Admission_Predict.csv')

# %% [markdown]
# Evaluemos el conjunto de datos mirando la función `head`.

# %%
# Tu código aquí
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        316          104                  3  3.0   3.5  8.00
# 2           3        322          110                  3  3.5   2.5  8.67
# 3           4        314          103                  2  2.0   3.0  8.21
# 4           5        330          115                  5  4.5   3.0  9.34
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.72
# 2         1              0.80
# 3         0              0.65
# 4         1              0.90

# %% [markdown]
# ### 1 - Antes de comenzar a trabajar con este conjunto de datos y evaluar los datos de admisiones de posgrado, verificaremos que no haya datos faltantes en el conjunto de datos. Haz esto en la celda de abajo.

# %%
# Tu código aquí

admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         385 non-null    int64
#  1   GRE Score          385 non-null    int64
#  2   TOEFL Score        385 non-null    int64
#  3   University Rating  385 non-null    int64
#  4   SOP                385 non-null    float64
#  5   LOR                385 non-null    float64
#  6   CGPA               385 non-null    float64
#  7   Research           385 non-null    int64
#  8   Chance of Admit    385 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 27.2 KB

# %% [markdown]
# ###  2 -  Curiosamente, hay una columna que identifica de manera única a los solicitantes. Esta columna es la columna de número de serie. En lugar de tener nuestro propio índice, deberíamos hacer de esta columna nuestro índice. Haz esto en la celda de abajo. Mantén la columna en el marco de datos además de hacerla un índice.

# %%
# Tu código aquí
admissions2 = pd.read_csv('C:/Users/manue/OneDrive/Documentos/IRONHACK Data Scientist/13 - Session XII Python APIs/LAB 1/Admission_Predict.csv',index_col='Serial No.')

admissions2
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 316          104                  3  3.0   3.5  8.00
# 3                 322          110                  3  3.5   2.5  8.67
# 4                 314          103                  2  2.0   3.0  8.21
# 5                 330          115                  5  4.5   3.0  9.34
# ...               ...          ...                ...  ...   ...   ...
# 381               324          110                  3  3.5   3.5  9.04
# 382               325          107                  3  3.0   3.5  9.11
# 383               330          116                  4  5.0   4.5  9.45
# 384               312          103                  3  3.5   4.0  8.78
# 385               333          117                  4  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.72
# 3                  1              0.80
# 4                  0              0.65
# 5                  1              0.90
# ...              ...               ...
# 381                1              0.82
# 382                1              0.84
# 383                1              0.91
# 384                0              0.67
# 385                1              0.95
#
# [385 rows x 8 columns]

# %% [markdown]
# Resulta que `GRE Score` y `CGPA` también identifican de manera única los datos. Muestra esto en la celda de abajo.
#
# ### 3 - En esta parte del laboratorio, nos gustaría probar condiciones complejas en todo el conjunto de datos de una vez. Comencemos encontrando el número de filas donde el CGPA es mayor a 9 y el estudiante ha realizado una investigación.

# %%
# Tu código aquí

admissions_9 = admissions2[(admissions2['CGPA']> 9) & (admissions2['Research']>0)]

admissions_9.count()
# Out:
# GRE Score            101
# TOEFL Score          101
# University Rating    101
# SOP                  101
# LOR                  101
# CGPA                 101
# Research             101
# Chance of Admit      101
# dtype: int64

# %% [markdown]
# ### 4 - Ahora devuelve todas las filas donde el CGPA es mayor a 9 y la puntuación SOP es menor a 3.5. Encuentra la probabilidad media de admisión para estos solicitantes.

# %%
# Tu código aquí

admissions_9_1 = admissions[(admissions['CGPA']> 9) & (admissions['SOP'] <= 3.5)]

admissions_9_1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 28           29        338          118                  4  3.0   4.5  9.40
# 62           63        327          114                  3  3.0   3.0  9.02
# 64           65        318          109                  3  3.5   4.0  9.22
# 99          100        326          112                  3  3.5   3.0  9.05
# 102         103        338          117                  4  3.5   4.5  9.46
# 123         124        326          112                  3  3.5   3.0  9.10
# 132         133        318          109                  1  3.5   3.5  9.12
# 140         141        326          114                  3  3.0   3.0  9.11
# 170         171        319          110                  3  3.5   3.5  9.04
# 217         218        324          111                  4  3.0   3.0  9.01
# 231         232        325          114                  3  3.5   3.0  9.04
# 311         312        326          116                  3  3.5   4.0  9.14
# 356         357        324          110                  3  3.5   3.0  9.22
# 380         381        324          110                  3  3.5   3.5  9.04
# 381         382        325          107                  3  3.0   3.5  9.11
#
#      Research  Chance of Admit
# 28          1              0.91
# 62          0              0.61
# 64          1              0.68
# 99          1              0.74
# 102         1              0.91
# 123         1              0.84
# 132         0              0.78
# 140         1              0.83
# 170         0              0.82
# 217         1              0.82
# 231         1              0.76
# 311         1              0.81
# 356         1              0.89
# 380         1              0.82
# 381         1              0.84

# %%
mean_admin = admissions_9_1[['Chance of Admit ']].mean()

print(f'La probabilidad media de admisión de este grupo de alumnos es {mean_admin}')
# Out:
# La probabilidad media de admisión de este grupo de alumnos es Chance of Admit     0.804
# dtype: float64
